# %%
import requests

# %%
url_get = 'http://httpbin.org/get'

# %%
payload = {"name" : "Joseph", "ID": "123"}

# %%
r = requests.get(url_get, params = payload)

# %%
r.url
# Out:
# 'http://httpbin.org/get?name=Joseph&ID=123'

# %%
r.request.body

# %%
r.status_code
# Out:
# 200

# %%
print(r.text)
# Out:
# {
#   "args": {
#     "ID": "123",
#     "name": "Joseph"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.5",
#     "X-Amzn-Trace-Id": "Root=1-69d9e314-57a8042b5cf3eec86564e9b3"
#   },
#   "origin": "42.112.79.99",
#   "url": "http://httpbin.org/get?name=Joseph&ID=123"
# }

# %%
r.headers
# Out:
# {'Date': 'Fri, 03 Apr 2026 03:50:13 GMT', 'Content-Type': 'application/json', 'Content-Length': '366', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}

# %%
r.json()
# Out:
# {'args': {'ID': '123', 'name': 'Joseph'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.32.5',
#   'X-Amzn-Trace-Id': 'Root=1-69cf38f5-01b7bade4bf1176741475552'},
#  'origin': '42.116.14.77',
#  'url': 'http://httpbin.org/get?name=Joseph&ID=123'}

# %%
r.json()['args']
# Out:
# {'ID': '123', 'name': 'Joseph'}

# %%
url_post = 'http://httpbin.org/post'
r_post = requests.post (url_post, data = payload)

# %%
r_post
# Out:
# <Response [200]>

# %%
print(r.request.body)
print(r_post.request.body)
# Out:
# None
# name=Joseph&ID=123

# %%
r_post.json()['form'] #voi get thi 'args'
# Out:
# {'ID': '123', 'name': 'Joseph'}

# %%
url_pic = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/data/Example1.txt'
r = requests.get(url_pic)
path = os.

# %%
r.status_code
# Out:
# 200
