# %%
''' 
- findChildren()
- title = soup.select('h1')
- vdL col = <tr> </tr> thì col.a = col.find('a')
- df["GDP_USD_millions"] = GDP_list
'''

# %%
# %%html
# <!DOCTYPE html>
# <html>
# <head>
#   <title>Page Title</title>
# </head>
# <body>
#   <h3><b id='boldest'> Lebron James </b></h3>
#   <p> Salary: $ 92,000,000 </p>
#   <h3> Stephen Curry </h3>
#   <p> Salary: $85,000,000 </p>
#   <h3> Kevin Durant </h3>
#   <p> Salary: $73,200,000 </p>
#   <p><a href = "https://www.coursera.org/my-learning?myLearningTab=IN_PROGRESS" target = "_blank">My Learning Data Engineering</a></p>
#
# </body>
# </html>
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#   <title>Page Title</title>
# </head>
# <body>
#   <h3><b id='boldest'> Lebron James </b></h3>
#   <p> Salary: $ 92,000,000 </p>
#   <h3> Stephen Curry </h3>
#   <p> Salary: $85,000,000 </p>
#   <h3> Kevin Durant </h3>
#   <p> Salary: $73,200,000 </p>
#   <p><a href = "https://www.coursera.org/my-learning?myLearningTab=IN_PROGRESS" target = "_blank">My Learning Data Engineering</a></p>
#
# </body>
# </html>

# %%
# %%html
# <!DOCTYPE html>
# <html>
# <head>
#     <title>HTML TABLE</title>
# </head>
# <body>
#     <table border = "1">
#         <tr>
#             <td>PizzaPlace</td>
#             <td>Orders</td>
#             <td>Slices</td>
#         </tr>
#         <tr>
#             <td>Domino Pizza</td>
#             <td>10</td>
#             <td>100</td>
#         </tr>
#         <tr>
#             <td>Little Caesars</td>
#             <td>12</td>
#             <td>144</td>
#         </tr>
#     </table>
# </body>
# </html>
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <title>HTML TABLE</title>
# </head>
# <body>
#     <table border = "1">
#         <tr>
#             <td>PizzaPlace</td>
#             <td>Orders</td>
#             <td>Slices</td>
#         </tr>
#         <tr>
#             <td>Domino Pizza</td>
#             <td>10</td>
#             <td>100</td>
#         </tr>
#         <tr>
#             <td>Little Caesars</td>
#             <td>12</td>
#             <td>144</td>
#         </tr>
#     </table>
# </body>
# </html>

# %%
from bs4 import BeautifulSoup

html = "<!DOCTYPE html><html><head><title>Page Title</title></head><body><h3><b id='boldest'> Lebron James </b></h3><p> Salary: $ 92,000,000 </p><h3> Stephen Curry </h3><p> Salary: $85,000,000 </p><h3> Kevin Durant </h3><p> Salary: $73,200,000 </p><p><a href = 'https://www.coursera.org/my-learning?myLearningTab=IN_PROGRESS'target = '_blank'>My Learning Data Engineering</a></p></body></html>"
soup = BeautifulSoup(html, 'html5lib')

# %% [markdown]
# ## find_all

# %%
soup.find_all('p') #Giong 1 list
# Out:
# [<p> Salary: $ 92,000,000 </p>,
#  <p> Salary: $85,000,000 </p>,
#  <p> Salary: $73,200,000 </p>,
#  <p><a href="https://www.coursera.org/my-learning?myLearningTab=IN_PROGRESS" target="_blank">My Learning Data Engineering</a></p>]

# %%
soup.title
# Out:
# <title>Page Title</title>

# %%
print("Co find out:", soup.find_all('h3'))
print("Khong co find out:", soup.h3)
# Out:
# Co find out: [<h3><b id="boldest"> Lebron James </b></h3>, <h3> Stephen Curry </h3>, <h3> Kevin Durant </h3>]
# Khong co find out: <h3><b id="boldest"> Lebron James </b></h3>

# %% [markdown]
# ## .parent

# %%
tag_cha = soup.h3
print(tag_cha)
tag_con = tag_cha.b #không cần dùng soup
print(tag_con)
print(tag_con.parent) #điều hướng lên cha
# Out:
# <h3><b id="boldest"> Lebron James </b></h3>
# <b id="boldest"> Lebron James </b>
# <h3><b id="boldest"> Lebron James </b></h3>

# %% [markdown]
# ## .sibling

# %%
sibling1 = tag_cha.next_sibling #cùng hàng - anh chị em
sibling1
# Out:
# <p> Salary: $ 92,000,000 </p>

# %%
sibling2 = sibling1.next_sibling
sibling2
# Out:
# <h3> Stephen Curry </h3>

# %% [markdown]
# ## table

# %%
html = '<!DOCTYPE html><html><head><title>HTML TABLE</title></head><body><table border = "1"><tr><td>PizzaPlace</td><td>Orders</td><td>Slices</td></tr><tr><td>Domino Pizza</td><td>10</td><td>100</td></tr><tr><td>Little Caesars</td><td>12</td><td>144</td></tr></table></body></html>'
table = BeautifulSoup(html,'html5lib')

# %%
table_row = table.find_all(name = 'tr')
table_row #type: bs4.element.ResultSet   --- vì nó tương tự list nên có thể dùng chỉ số để gọi
# Out:
# [<tr><td>PizzaPlace</td><td>Orders</td><td>Slices</td></tr>,
#  <tr><td>Domino Pizza</td><td>10</td><td>100</td></tr>,
#  <tr><td>Little Caesars</td><td>12</td><td>144</td></tr>]

# %%
first_row = table_row[0]
print(first_row)
first_row.find_all('td')
# Out:
# <tr><td>PizzaPlace</td><td>Orders</td><td>Slices</td></tr>
# [<td>PizzaPlace</td>, <td>Orders</td>, <td>Slices</td>]

# %%
#dung ham con - cha la 'tr' con la 'td'
first_row.td #duoc hieu la o dau tien cua hang 1 cua table
# Out:
# <td>PizzaPlace</td>

# %%
for i, row in enumerate(table_row):
    print("row:", i)
    #row gom 3 cells ne can chia no ra thanh 1 list 3 elements
    cells = row.find_all('td')

    for j, cell in enumerate(cells):
        print("column :",j,"cell :",cell)
# Out:
# row: 0
# column : 0 cell : <td>PizzaPlace</td>
# column : 1 cell : <td>Orders</td>
# column : 2 cell : <td>Slices</td>
# row: 1
# column : 0 cell : <td>Domino Pizza</td>
# column : 1 cell : <td>10</td>
# column : 2 cell : <td>100</td>
# row: 2
# column : 0 cell : <td>Little Caesars</td>
# column : 1 cell : <td>12</td>
# column : 2 cell : <td>144</td>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
page = requests.get("https://quotes.toscrape.com/").text

soup = BeautifulSoup(page,'html.parser')

artists = soup.find_all('a')
#artists[0].contents # luon tra ve 1 list:   ['Books to Scrape'] --- nen phai dung [0]
#artists[0].get_text() # 'Books to Scrape'
data = []

for artist in artists:
    name = artist.get_text().replace(' ', '').replace('\n','')
    link = artist.get('href')
    data.append({'Name': name, 'Link': link})

df = pd.DataFrame(data)
df
# Out:
#                                Name  \
# 0                    QuotestoScrape
# 1                             Login
# 2                           (about)
# 3                            change
# 4                     deep-thoughts
# 5                          thinking
# 6                             world
# 7                           (about)
# 8                         abilities
# 9                           choices
# 10                          (about)
# 11                    inspirational
# 12                             life
# 13                             live
# 14                          miracle
# 15                         miracles
# 16                          (about)
# 17                        aliteracy
# 18                            books
# 19                          classic
# 20                            humor
# 21                          (about)
# 22                      be-yourself
# 23                    inspirational
# 24                          (about)
# ...

# %% [markdown]
# ## EXERCICE

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
html="<!DOCTYPE html><html><head><title>Page Title</title></head><body><h3><b id='boldest'>Lebron James</b></h3><p> Salary: $ 92,000,000 </p><h3> Stephen Curry</h3><p> Salary: $85,000, 000 </p><h3> Kevin Durant </h3><p> Salary: $73,200, 000</p></body></html>"
soup = BeautifulSoup(html, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Page Title
#   </title>
#  </head>
#  <body>
#   <h3>
#    <b id="boldest">
#     Lebron James
#    </b>
#   </h3>
#   <p>
#    Salary: $ 92,000,000
#   </p>
#   <h3>
#    Stephen Curry
#   </h3>
#   <p>
#    Salary: $85,000, 000
#   </p>
#   <h3>
#    Kevin Durant
#   </h3>
#   <p>
#    Salary: $73,200, 000
#   </p>
#  </body>
# </html>

# %% [markdown]
# ## Tag

# %%
tag_object = soup.h3
tag_object
# Out:
# <h3><b id="boldest">Lebron James</b></h3>

# %%
type(tag_object)
# Out:
# bs4.element.Tag

# %%
soup.h3
# Out:
# <h3><b id="boldest">Lebron James</b></h3>

# %% [markdown]
# ## Children, Parents and Sibling
# next_sibling

# %%
tag_child = tag_object.b
tag_child
# Out:
# <b id="boldest">Lebron James</b>

# %%
tag_child.parent
# Out:
# <h3><b id="boldest">Lebron James</b></h3>

# %%
tag_object.next_sibling
# Out:
# <p> Salary: $ 92,000,000 </p>

# %% [markdown]
# ## HTML Attributes

# %%
tag_child['id']
# Out:
# 'boldest'

# %%
tag_child.attrs
# Out:
# {'id': 'boldest'}

# %%
#lấy nội dung thuộc tính của thẻ bằng pp get()
tag_child.get('id')
# Out:
# 'boldest'

# %% [markdown]
# ## Navigable String

# %%
tag_string = tag_object.next_sibling.string
print(tag_string) #lấy phần text ben trong thẻ
type(tag_string) #ngoài việc có thể sử dụng 1 số tool trên beautifulsoup thì có thể chuyển nó thành str
# Out:
#  Salary: $ 92,000,000
# bs4.element.NavigableString

# %%
str_tag = str(tag_string)
print(str_tag)
type(str_tag)
# Out:
#  Salary: $ 92,000,000
# str

# %% [markdown]
# ## Filter

# %%
# %%html
# <table>
#   <tr>
#     <td id='flight' >Flight No</td>
#     <td>Launch site</td>
#     <td>Payload mass</td>
#    </tr>
#   <tr>
#     <td>1</td>
#     <td><a href='https://en.wikipedia.org/wiki/Florida'>Florida</a></td>
#     <td>300 kg</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td><a href='https://en.wikipedia.org/wiki/Texas'>Texas</a></td>
#     <td>94 kg</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a> </td>
#     <td>80 kg</td>
#   </tr>
# </table>
# Out:
# <table>
#   <tr>
#     <td id='flight' >Flight No</td>
#     <td>Launch site</td>
#     <td>Payload mass</td>
#    </tr>
#   <tr>
#     <td>1</td>
#     <td><a href='https://en.wikipedia.org/wiki/Florida'>Florida</a></td>
#     <td>300 kg</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td><a href='https://en.wikipedia.org/wiki/Texas'>Texas</a></td>
#     <td>94 kg</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a> </td>
#     <td>80 kg</td>
#   </tr>
# </table>

# %%
table="<table><tr><td id='flight'>Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr> <td>1</td><td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a></td><td>300 kg</td></tr><tr><td>2</td><td><a href='https://en.wikipedia.org/wiki/Texas'>Texas</a></td><td>94 kg</td></tr><tr><td>3</td><td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a> </td><td>80 kg</td></tr></table>"
table_bs = BeautifulSoup(table, 'html.parser')

# %%
table_row = table_bs.find_all('tr')
table_row
# Out:
# [<tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>,
#  <tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td><td>300 kg</td></tr>,
#  <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>,
#  <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td><td>80 kg</td></tr>]

# %%
first_row = table_row[0]
print(first_row)
type(first_row)
#first_row.name - in ra thẻ của nó
# Out:
# <tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>
# bs4.element.Tag

# %%
first_row.td
# Out:
# <td id="flight">Flight No</td>

# %%
for i, row in enumerate(table_row):
    print("row:", i)
    cells = row.find_all('td')
    for j, cell in enumerate(cells):
        print('column:', j,'- cell:',cell)
# Out:
# row: 0
# column: 0 - cell: <td id="flight">Flight No</td>
# column: 1 - cell: <td>Launch site</td>
# column: 2 - cell: <td>Payload mass</td>
# row: 1
# column: 0 - cell: <td>1</td>
# column: 1 - cell: <td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td>
# column: 2 - cell: <td>300 kg</td>
# row: 2
# column: 0 - cell: <td>2</td>
# column: 1 - cell: <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>
# column: 2 - cell: <td>94 kg</td>
# row: 3
# column: 0 - cell: <td>3</td>
# column: 1 - cell: <td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td>
# column: 2 - cell: <td>80 kg</td>

# %%
list_input = table_bs.find_all(name = ['tr','td'])
list_input #in ra <tr> sau đó in ra <td> của <tr> đó
# Out:
# [<tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>,
#  <td id="flight">Flight No</td>,
#  <td>Launch site</td>,
#  <td>Payload mass</td>,
#  <tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td><td>300 kg</td></tr>,
#  <td>1</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td>,
#  <td>300 kg</td>,
#  <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>,
#  <td>2</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>,
#  <td>94 kg</td>,
#  <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td><td>80 kg</td></tr>,
#  <td>3</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td>,
#  <td>80 kg</td>]

# %%
table_bs.find_all(id = 'flight')
# Out:
# [<td id="flight">Flight No</td>]

# %%
table_bs.find_all(href = "https://en.wikipedia.org/wiki/Florida")
# Out:
# [<a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a>,
#  <a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a>]

# %%
table_bs.find_all(href = True)
# Out:
# [<a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a>,
#  <a href="https://en.wikipedia.org/wiki/Texas">Texas</a>,
#  <a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a>]

# %%
# tìm tất cả thẻ a mà ko có link
table_bs.find_all(lambda tag : tag.name == 'a' and not tag.has_attr('href'))
# Out:
# [<a></a>, <a> </a>]

# %%
#tìm tất cả thẻ ko chưa link
table_bs.find_all(lambda tag: tag.name != 'a' and not tag.find('a'))
# Out:
# [<tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>,
#  <td id="flight">Flight No</td>,
#  <td>Launch site</td>,
#  <td>Payload mass</td>,
#  <td>1</td>,
#  <td>300 kg</td>,
#  <td>2</td>,
#  <td>94 kg</td>,
#  <td>3</td>,
#  <td>80 kg</td>]

# %%
# %%html
# <h3>Rocket Launch </h3>
#
# <p>
# <table class='rocket'>
#   <tr>
#     <td>Flight No</td>
#     <td>Launch site</td>
#     <td>Payload mass</td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Florida</td>
#     <td>300 kg</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td>Texas</td>
#     <td>94 kg</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>Florida </td>
#     <td>80 kg</td>
#   </tr>
# </table>
# </p>
# <p>
#
# <h3>Pizza Party  </h3>
#
#
# <table class='pizza'>
#   <tr>
#     <td>Pizza Place</td>
#     <td>Orders</td>
#     <td>Slices </td>
#    </tr>
#   <tr>
#     <td>Domino's Pizza</td>
#     <td>10</td>
#     <td>100</td>
#   </tr>
#   <tr>
#     <td>Little Caesars</td>
#     <td>12</td>
#     <td >144 </td>
#   </tr>
#   <tr>
#     <td>Papa John's </td>
#     <td>15 </td>
#     <td>165</td>
#   </tr>
# Out:
# <h3>Rocket Launch </h3>
#
# <p>
# <table class='rocket'>
#   <tr>
#     <td>Flight No</td>
#     <td>Launch site</td>
#     <td>Payload mass</td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Florida</td>
#     <td>300 kg</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td>Texas</td>
#     <td>94 kg</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>Florida </td>
#     <td>80 kg</td>
#   </tr>
# </table>
# </p>
# <p>
#
# <h3>Pizza Party  </h3>
#
#
# <table class='pizza'>
#   <tr>
#     <td>Pizza Place</td>
#     <td>Orders</td>
#     <td>Slices </td>
#    </tr>
#   <tr>
#     <td>Domino's Pizza</td>
#     <td>10</td>
#     <td>100</td>
#   </tr>
#   <tr>
#     <td>Little Caesars</td>
#     <td>12</td>
#     <td >144 </td>
#   </tr>
#   <tr>
#     <td>Papa John's </td>
#     <td>15 </td>
#     <td>165</td>
#   </tr>

# %%
two_tables="<h3>Rocket Launch </h3><p><table class='rocket'><tr><td>Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr><td>1</td><td>Florida</td><td>300 kg</td></tr><tr><td>2</td><td>Texas</td><td>94 kg</td></tr><tr><td>3</td><td>Florida </td><td>80 kg</td></tr></table></p><p><h3>Pizza Party  </h3><table class='pizza'><tr><td>Pizza Place</td><td>Orders</td> <td>Slices </td></tr><tr><td>Domino's Pizza</td><td>10</td><td>100</td></tr><tr><td>Little Caesars</td><td>12</td><td >144 </td></tr><tr><td>Papa John's </td><td>15 </td><td>165</td></tr>"
two_tables_bs = BeautifulSoup(two_tables, 'html.parser')

# %%
two_tables_bs.find('table') #co 2 the table
# Out:
# <table class="rocket"><tr><td>Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr><td>1</td><td>Florida</td><td>300 kg</td></tr><tr><td>2</td><td>Texas</td><td>94 kg</td></tr><tr><td>3</td><td>Florida </td><td>80 kg</td></tr></table>

# %%
two_tables_bs.find("table",class_= 'pizza') #attrs = {'class': 'pizza'} ----- find(tag, attrs)
# Out:
# <table class="pizza"><tr><td>Pizza Place</td><td>Orders</td> <td>Slices </td></tr><tr><td>Domino's Pizza</td><td>10</td><td>100</td></tr><tr><td>Little Caesars</td><td>12</td><td>144 </td></tr><tr><td>Papa John's </td><td>15 </td><td>165</td></tr></table>

# %% [markdown]
# ## LINK

# %%
url = "http://www.ibm.com"
data = requests.get(url).text
soup = BeautifulSoup(data, 'html.parser')
# Out:
# ' \n<!DOCTYPE HTML>\n\n<html lang="en">\n<head>\r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n      \r\n    \r\n    \r\n    \r\n    \r\n    <meta charset="UTF-8"/>\r\n    <meta name="languageCode" content="en"/>\r\n    <meta name="countryCode" content="us"/>\r\n    <meta name="searchTitle" content="IBM"/>\r\n    <meta name="focusArea" content="Cross IBM SDRs"/>\r\n    <meta name=\'primaryTaxonomyEn\' content="IBM"/>\r\n    <meta name="siteSection" content="home"/>\r\n    <meta name="primaryTopic" content="IBM"/>\r\n    <meta name="productName"/>\r\n    <meta name="pageType"/>\r\n    <title>IBM</title>\r\n      <meta name="content-page-ref" content="eROxip4tByGTXXkYPHZou7oTgw2e0GMdApm2VHP9JNKXdpCWq8mPAxUAd36QHdh0uX5DLAELN8kcObodQWtduQ"/>\n<script defer="defer" type="text/javascript" src="https://rum.hlx.page/.rum/@adobe/helix-rum-js@%5E2/dist/micro.js" data-routing="program=131558,environment=1281329,tier=publish"></script>\n<link rel="icon" sizes="16x16" href="/content/d
# ...

# %%
for link in soup.find_all('a',href = True):
    print(link.get('href'))
# Out:
# https://www.ibm.com/events/think?lnk=hpprus&utm_id=PBushp
# https://www.ibm.com/sports/masters?lnk=hpls1us
# https://www.ibm.com/think/insights/lets-create-smarter-business?lnk=hpls2us
# https://newsroom.ibm.com/2026-03-23-ibm-debuts-new-ai-enabled-digital-experiences-for-the-90th-masters-tournament?lnk=hprc1us
# https://www.ibm.com/consulting/data-ai?lnk=hprc2us
# https://www.ibm.com/solutions/ai-agents?lnk=hprc3us
# https://www.ibm.com/think/news/companies-stop-building-ai-agents-start-running-them?lnk=hprc4us
# https://www.ibm.com/case-studies/us-open?lnk=hpcs2us
# https://www.ibm.com/case-studies/pfizer?lnk=hpcs3us
# https://www.ibm.com/case-studies/ufc?lnk=hpcs1us
# https://www.ibm.com/case-studies/scuderia-ferrari?lnk=hpcs4us
# https://www.ibm.com/products/offers-and-discounts?lnk=hpdo1us
# https://www.ibm.com/software?lnk=hpfp1us
# https://www.ibm.com/software/ai-productivity?lnk=hpfp2us
# https://www.ibm.com/software/data-management?lnk=hpfp3us
# ...

# %%
for link in soup.find_all('img'):
    print(link)
    print(link.get('src'))
# Out:
# <img alt="Mobile screen displaying the Masters Vault app" class="cmp-image__image" height="1201" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/homepage-masters2026-r4u-1?ts=1775648838932&amp;dpr=off" srcset="..." title="Mobile screen showing Masters Vault 1986 golf final" width="1200"/>
# https://assets.ibm.com/is/image/ibm/homepage-masters2026-r4u-1?ts=1775648838932&dpr=off
# <img alt="Illustration of golf elements in a grid" class="cmp-image__image" height="1080" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/ibm_masters_2d_illos_1x1_08?ts=1775574406246&amp;dpr=off" srcset="..." title="Golf-themed collage with club and ball" width="1080"/>
# https://assets.ibm.com/is/image/ibm/ibm_masters_2d_illos_1x1_08?ts=1775574406246&dpr=off
# ...

# %% [markdown]
# ## Table

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/HTMLColorCodes.html'
data = requests.get(url).text
soup = BeautifulSoup(data, 'html.parser')

# %%
table = soup.find('table')
table #giong str, khac find_all tra ve kieu giong list
# Out:
# bs4.element.Tag

# %%
for row in table.find_all('tr'):
    cells = row.find_all('td')
    col_name = cells[2].string
    col_code = cells[3].string
    print('{} ---> {}'.format(col_name, col_code))
# Out:
# Color Name ---> None
# lightsalmon ---> #FFA07A
# salmon ---> #FA8072
# darksalmon ---> #E9967A
# lightcoral ---> #F08080
# coral ---> #FF7F50
# tomato ---> #FF6347
# orangered ---> #FF4500
# gold ---> #FFD700
# orange ---> #FFA500
# darkorange ---> #FF8C00
# lightyellow ---> #FFFFE0
# lemonchiffon ---> #FFFACD
# papayawhip ---> #FFEFD5
# moccasin ---> #FFE4B5
# peachpuff ---> #FFDAB9
# palegoldenrod ---> #EEE8AA
# khaki ---> #F0E68C
# darkkhaki ---> #BDB76B
# yellow ---> #FFFF00
# lawngreen ---> #7CFC00
# chartreuse ---> #7FFF00
# limegreen ---> #32CD32
# lime ---> #00FF00
# forestgreen ---> #228B22
# green ---> #008000
# powderblue ---> #B0E0E6
# lightblue ---> #ADD8E6
# lightskyblue ---> #87CEFA
# skyblue ---> #87CEEB
# deepskyblue ---> #00BFFF
# lightsteelblue ---> #B0C4DE
# dodgerblue ---> #1E90FF
