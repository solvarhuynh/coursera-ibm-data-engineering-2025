# %%
import pandas as pd 
import sqlite3

# %%
df = pd.read_excel("diemthi.xlsx")
df
# Out:
#      Số thứ tự Lớp 12       Số CMND           Họ và tên Giới tính   Ngày sinh  \
# 0          NaN    NaN           NaN                 NaN       NaN         NaN
# 1        205.0   12A5  5.230602e+10    TRƯƠNG THỊ NHƯ Ý        Nữ  09/05/2006
# 2        204.0   12A5  5.230601e+10        PHẠM THÚY VY        Nữ  19/05/2006
# 3        203.0   12A5  5.220601e+10      CAO QUỐC VƯƠNG       Nam  10/08/2006
# 4        202.0   12A5  5.230600e+10  NGUYỄN ĐẶNG YẾN VI        Nữ  22/09/2006
# ..         ...    ...           ...                 ...       ...         ...
# 201        5.0   12A1  5.230601e+10       DIỆP HIỀN HẢI        Nữ  03/06/2006
# 202        4.0   12A1  5.230601e+10     LƯU HỒ MỸ DUYÊN        Nữ  02/04/2006
# 203        3.0   12A1  5.220600e+10    HUỲNH QUỐC CƯỜNG       Nam  06/12/2006
# 204        2.0   12A1  5.230600e+10          LÊ THỊ CHI        Nữ  23/01/2006
# 205        1.0   12A1  5.230601e+10  NGUYỄN HÀ NHẬT ÁNH        Nữ  29/05/2006
#
# ...

# %%
con = sqlite3.connect("diemthi.db")
df.to_sql("BANG DIEM", con, if_exists = "replace", index=False, method="multi")
# Out:
# 206

# %%
# !pip install ipython-sql prettytable
import prettytable, csv
prettytable.DEFAULT = "DEFAULT"

# %%
# !pip install ipython-sql
# %load_ext sql

# %%
# %sql sqlite:///diemthi.db

# %%
# %sql select * from BANGDIEM LIMIT 10
# Out:
#  * sqlite:///diemthi.db
# Done.
# [(None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  (205.0, '12A5', 52306016686.0, 'TRƯƠNG THỊ NHƯ Ý', 'Nữ', '09/05/2006', 'BÌNH ĐỊNH', 'Kinh', '37-Hội đồng thi Sở GD&ĐT Bình Định', 7.2, 6.0, 8.0, 6.75, 6.25, None, None, None, 5.0, 'N1'),
#  (204.0, '12A5', 52306011663.0, 'PHẠM THÚY VY', 'Nữ', '19/05/2006', 'BÌNH ĐỊNH', 'Kinh', '37-Hội đồng thi Sở GD&ĐT Bình Định', 5.0, 6.5, None, None, None, 6.75, 7.0, 7.5, 5.0, 'N1'),
#  (203.0, '12A5', 52206010518.0, 'CAO QUỐC VƯƠNG', 'Nam', '10/08/2006', 'BÌNH ĐỊNH', 'Kinh', '37-Hội đồng thi Sở GD&ĐT Bình Định', 8.2, 5.25, 9.5, 9.0, 5.25, None, None, None, 4.0, 'N1'),
#  (202.0, '12A5', 52306003936.0, 'NGUYỄN ĐẶNG YẾN VI', 'Nữ', '22/09/2006', 'BÌNH ĐỊNH', 'Kinh', '37-Hội đồng thi Sở GD&ĐT Bình Định', 5.8, 6.75, None, None, None, 6.5, 7.0, 6.75, 5.6, 'N1'),
# ...

# %%
# %sql SELECT `lớp 12`, `Họ và tên`, Toán, `Vật lí`, `Hóa học`, (Toán + `Vật lí` + `Hóa học`) AS TongDiem FROM BANGDIEM ORDER BY TongDiem DESC
# Out:
#  * sqlite:///diemthi.db
# Done.
# [('12A1', 'NGUYỄN THỊ TƯỜNG VY', 9.4, 8.5, 9.0, 26.9),
#  ('12A1', 'ĐỖ ĐỨC DUY THẮNG', 8.8, 9.0, 9.0, 26.8),
#  ('12A5', 'CAO QUỐC VƯƠNG', 8.2, 9.5, 9.0, 26.7),
#  ('12A4', 'NGUYỄN CHÍ NHÂN', 8.6, 8.75, 9.25, 26.6),
#  ('12A2', 'HUỲNH TRUNG NGHĨA', 9.0, 8.75, 8.75, 26.5),
#  ('12A1', 'GIANG THỊ NGÂN', 8.6, 8.25, 9.5, 26.35),
#  ('12A1', 'TRẦN PHÚ THÀNH', 8.8, 8.25, 8.75, 25.8),
#  ('12A1', 'TRẦN MINH TƯỜNG', 9.0, 8.5, 8.0, 25.5),
#  ('12A1', 'NGUYỄN NHẬT VY', 7.6, 9.0, 8.75, 25.35),
#  ('12A3', 'NGUYỄN PHÚC NGUYÊN', 8.6, 8.25, 8.25, 25.1),
#  ('12A1', 'NGUYỄN CHÍ NHÂN', 8.2, 8.75, 8.0, 24.95),
#  ('12A1', 'NGUYỄN KIỀU VY', 8.4, 8.75, 7.75, 24.9),
#  ('12A2', 'VÕ HỒNG VIÊN', 8.0, 8.25, 8.5, 24.75),
#  ('12A1', 'NGUYỄN THỊ DIỂM SƯƠNG', 8.4, 8.75, 7.5, 24.65),
#  ('12A1', 'TRẦN HUỲNH NGỌC LONG', 8.4, 8.5, 7.75, 24.65),
#  ('12A5', 'LÊ MAI TRUNG HIẾU', 7.8, 8.25, 8.5, 24.55),
#  ('12A5', 'TRẦN NGUYỄN KIM HIỀN', 7.8, 8.5, 8.25, 24.55),
# ...
